# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation, rc
import numpy as np

rc('animation', html='html5')

COVID19_MALAY = "covid-19-malaysia.csv"

FONT_SIZE = 20

main_df = pd.read_csv(COVID19_MALAY, header=0)
print(main_df)
# Out:
#          date   cases  discharged  death   icu
# 0   24/1/2020     0.0         0.0    0.0   0.0
# 1   25/1/2020     3.0         0.0    0.0   0.0
# 2   26/1/2020     4.0         0.0    0.0   0.0
# 3   27/1/2020     4.0         0.0    0.0   0.0
# 4   28/1/2020     4.0         0.0    0.0   0.0
# ..        ...     ...         ...    ...   ...
# 63  27/3/2020  2161.0       259.0   26.0  54.0
# 64  28/3/2020  2320.0       320.0   27.0  73.0
# 65  29/3/2020  2470.0       388.0   34.0  73.0
# 66  30/3/2020  2626.0       479.0   37.0  94.0
# 67  31/3/2020     NaN         NaN    NaN   NaN
#
# [68 rows x 5 columns]

# %%
# Trajectory of Confirmed Cases - DAILY

def calc_newcases_daily(cases):
    newcases_daily = pd.Series(np.zeros(cases.size))
    for i, v in cases.items():
        if i == 0:
            newcases_daily[i] = v
        else:
            newcases_daily[i] = v-cases[i-1]
    
    return newcases_daily

nc_d = calc_newcases_daily(pd.Series(main_df['cases']))

# Animation of plot over time (DAILY)
fig, ax = plt.subplots(figsize=(12, 9))
plt.title("Trajectory of COVID-19 Confirmed Cases in Malaysia", fontsize=FONT_SIZE)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Total Confirmed Cases", fontsize=FONT_SIZE)
plt.ylabel("New Confirmed Cases (In the Past Day)", fontsize=FONT_SIZE)

ax.set_xlim(1, np.max(main_df['cases'])*10)
ax.set_ylim(1, np.max(nc_d)*10)
ax.grid()
date = ax.text(np.max(main_df['cases']), 2, "", fontsize=FONT_SIZE)
line, = ax.plot([], [], 'r')

fig.text(0.9, 0.15, 'zim96@GitHub', fontsize=50, color='gray', ha='right', va='bottom', alpha=0.5, rotation=45)

def init():
    line.set_data([], [])
    date.set_text("date")
    return line,

def animate(i):
    line.set_data(main_df['cases'][0:i], nc_d[0:i])
    date.set_text(main_df['date'][i])
    return line,

ani = animation.FuncAnimation(fig, animate, main_df['cases'].size, init_func=init, blit=True, interval=200)
ani
# Out:
# <video width="864" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Trajectory of Confirmed Cases - WEEKLY

def calc_newcases_weekly(cases):
    newcases_weekly = pd.Series(np.zeros(cases.size))
    
    for i, v in cases.items():
        if i == 0:
            newcases_weekly[i] = v
        else:
            min_i = np.max([0, i-7])
            newcases_weekly[i] = v-cases[min_i]
    
    return newcases_weekly

nc_w = calc_newcases_weekly(pd.Series(main_df['cases']))

# Animation of plot over time (WEEKLY)
fig, ax = plt.subplots(figsize=(12, 9))
plt.title("Trajectory of COVID-19 Confirmed Cases in Malaysia", fontsize=FONT_SIZE)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Total Confirmed Cases", fontsize=FONT_SIZE)
plt.ylabel("New Confirmed Cases (In the Past Week)", fontsize=FONT_SIZE)

ax.set_xlim(1, np.max(main_df['cases'])*10)
ax.set_ylim(1, np.max(nc_w)*10)
ax.grid()
date = ax.text(np.max(main_df['cases']), 2, "", fontsize=FONT_SIZE)
line, = ax.plot([], [], 'r')

fig.text(0.9, 0.15, 'zim96@GitHub', fontsize=50, color='gray', ha='right', va='bottom', alpha=0.5, rotation=45)

def init():
    line.set_data([], [])
    date.set_text("date")
    return line,

def animate(i):
    line.set_data(main_df['cases'][0:i], nc_w[0:i])
    date.set_text(main_df['date'][i])
    return line,

ani = animation.FuncAnimation(fig, animate, main_df['cases'].size, init_func=init, blit=True, interval=200)
ani
# Out:
# <video width="864" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Trajectory of Confirmed Cases - FORTNIGHT

def calc_newcases_fortnight(cases):
    newcases_fortnight = pd.Series(np.zeros(cases.size))
    
    for i, v in cases.items():
        if i == 0:
            newcases_fortnight[i] = v
        else:
            min_i = np.max([0, i-14])
            newcases_fortnight[i] = v-cases[min_i]
    
    return newcases_fortnight

nc_fn = calc_newcases_fortnight(pd.Series(main_df['cases']))

# Animation of plot over time (fortnight)
fig, ax = plt.subplots(figsize=(12, 9))
plt.title("Trajectory of COVID-19 Confirmed Cases in Malaysia", fontsize=FONT_SIZE)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Total Confirmed Cases", fontsize=FONT_SIZE)
plt.ylabel("New Confirmed Cases (In the Past Fortnight)", fontsize=FONT_SIZE)

ax.set_xlim(1, np.max(main_df['cases'])*10)
ax.set_ylim(1, np.max(nc_fn)*10)
ax.grid()
date = ax.text(np.max(main_df['cases']), 2, "", fontsize=FONT_SIZE)
line, = ax.plot([], [], 'r')

fig.text(0.9, 0.15, 'zim96@GitHub', fontsize=50, color='gray', ha='right', va='bottom', alpha=0.5, rotation=45)

def init():
    line.set_data([], [])
    date.set_text("date")
    return line,

def animate(i):
    line.set_data(main_df['cases'][0:i], nc_fn[0:i])
    date.set_text(main_df['date'][i])
    return line,

ani = animation.FuncAnimation(fig, animate, main_df['cases'].size, init_func=init, blit=True, interval=200)
ani
# Out:
# <video width="864" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...
